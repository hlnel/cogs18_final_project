# %% [markdown]
# # Project Description

# %% [markdown]
# Hi there!
#
# In this project, I created a choose-your-own-adventure style ChatBot that allows you to create a character and go on quests. You have multiple choices that could determine your fate and the outcomes to each choice is specific to each player and depends on the player's stats from when they first created their character. With successful completion of each quest, the player can continue to embark on more adventures, strengthening themselves and improving their stats through every action they choose to do.
#
# To start your adventure, type 'monster_quest()'.

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
from my_module.functions import monster_quest, cave, adventure_quests, player_death, loot, menu
from my_module.functions import direct_attack, cast_spell, shoot_arrow
from random import choice

# %%
# test it out
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.5, pytest-6.2.5, py-1.10.0, pluggy-1.0.0
# rootdir: /home/hhle/FinalProject_COGS18_WI22
# plugins: anyio-3.2.1
# collected 6 items
#
# my_module/test_functions.py ......                                       [100%]
#
# ============================== 6 passed in 0.04s ===============================

# %%
monster_quest()
# Out:
# What's your name, traveller?Helen
#
# Hello there, Helen! Welcome to Monster Quest (default mode)!
# You're dirt poor, right now! Broke! Penniless, in fact!
# The only way this could get worse is if you got yourself in some deep,
# deep debt but we'll be saving that for you at a later time ;)
# At this moment, you'll be picking your class and doing quests,
# fighting monsters and (hopefully) earning that well-needed bag!
# How well you do is determined by the stats of your character and
# your overall luck! It wouldn't be any fun otherwise now, would it?
#
# Now, what would you like your character class to be?
# The options are:
# - Warrior
# - Mage
# - Rogue
# - Archer
# If you're confused about each class or would like to know
# their detailed stats, type 'help'.
# help
# Need some help? Here's a description of each class:
# WARRIOR:
# - A close-range fighter that attacks with their brute strength.
# - STR: 15, INT: 5, DEX: 5, LUK: 5
# MAGE:
# ...

# %% [markdown]
# #### Extra Credit (*optional*)
#
# 1. Before this course, my Python background was non-existent and I've never taken a coding class or anything of the sort before.
# 2. I believe my project went above and beyond the requirements of the project because I created multiple classes that were later used to create Class Objects in the Chatbot, which were referenced as function parameters to execute the desired outcomes based on the Objects' instance attributes. I challenged myself with using these Class Objects and writing conditionals and loops to make this choose-your-adventure story as personalized and seamless as I could while trying to avoid nested code.
